# %% [markdown]
# 이 코드의 문서 : https://www.notion.so/GEARS-perturb-seq-bc7280ec1fad407291d6f8145df9c068?pvs=4

# %%
import scanpy
import pandas as pd
import anndata
import os
os.chdir("/media/hdd/hb/lof/perturb_seq/geo_raw_data/jost_gse132080")

# %%
barcode  = pd.read_csv(f"/media/hdd/hb/lof/perturb_seq/geo_raw_data/jost_gse132080/GSE132080_10X_barcodes.tsv", sep='\t',)
cell_info = pd.read_csv(f"/media/hdd/hb/lof/perturb_seq/geo_raw_data/jost_gse132080/GSE132080_sgRNA_barcode_sequences_and_phenotypes.csv")
gene_info = pd.read_csv(f"/media/hdd/hb/lof/perturb_seq/geo_raw_data/jost_gse132080/GSE132080_10X_genes.tsv",)
len(barcode)
# Out:
# 23632

# %%
barcode
# Out:
#        AAACCTGAGAGTAATC-1
# 0      AAACCTGAGGGATCTG-1
# 1      AAACCTGAGGTCATCT-1
# 2      AAACCTGCAATGGAGC-1
# 3      AAACCTGCACCAGGCT-1
# 4      AAACCTGCACCATCCT-1
# ...                   ...
# 23627  TTTGTCAGTTTGACTG-3
# 23628  TTTGTCAGTTTGTTGG-3
# 23629  TTTGTCATCACAAACC-3
# 23630  TTTGTCATCAGCATGT-3
# 23631  TTTGTCATCTTAGAGC-3
#
# [23632 rows x 1 columns]

# %%
cell_info
# Out:
#                       sgRNA_name              sequence   gene  gamma_day5  \
# 0    ALDOA_+_30077139.23-P1P2_00  GGTCACCAGGACCCCTTCTG  ALDOA   -0.412746
# 1    ALDOA_+_30077139.23-P1P2_06  GGTCACCAGGATCCCTTCTG  ALDOA   -0.396687
# 2    ALDOA_+_30077139.23-P1P2_07  GGTCACCAGGCCCCCTTCTG  ALDOA   -0.360892
# 3    ALDOA_+_30077139.23-P1P2_13  GGTCACCAGGACCCCTTTTG  ALDOA    0.017063
# 4    ALDOA_+_30077139.23-P1P2_14  GGTCACCAGGACCGCTTCTG  ALDOA   -0.175243
# ..                           ...                   ...    ...         ...
# 123     TUBB_+_30688126.23-P1_00  GCGGCAGGAAGGTTCTGAGA   TUBB   -0.897047
# 124     TUBB_+_30688126.23-P1_01  GCAGCAGGAAGGTTCTGAGA   TUBB   -0.925988
# 125     TUBB_+_30688126.23-P1_03  GCGGCAGCAAGGTTCTGAGA   TUBB   -0.692569
# 126     TUBB_+_30688126.23-P1_06  GCGGCAGGACGGTTCTGAGA   TUBB   -0.730802
# 127     TUBB_+_30688126.23-P1_10  GCGGCAGGAAGGTTCAGAGA   TUBB   -0.197800
#
#      gamma_day10  relative_activity_day5  relative_activity_day10
# 0      -0.366469                1.000000                 1.000000
# 1      -0.348503                0.961091                 0.950977
# 2      -0.335059                0.874369                 0.914291
# 3      -0.000220               -0.041340                 0.000601
# 4      -0.156611                0.424579                 0.427353
# ..           ...                     ...                      ...
# 123    -0.699905                1.000000                 1.000000
# 124    -0.611949                1.032262                 0.874332
# 125    -0.495873                0.772054                 0.708486
# 126    -0.554446                0.814676                 0.792174
# 127    -0.145079                0.220501                 0.207283
#
# [128 rows x 7 columns]

# %%
cell_info[cell_info['sequence']=='AAACCTGAGAGTAATC-1']
# Out:
# Empty DataFrame
# Columns: [sgRNA_name, sequence, gene, gamma_day5, gamma_day10, relative_activity_day5, relative_activity_day10]
# Index: []

# %%
gene_info
# Out:
#        AAACCTGAGAGTAATC-1
# 0      AAACCTGAGGGATCTG-1
# 1      AAACCTGAGGTCATCT-1
# 2      AAACCTGCAATGGAGC-1
# 3      AAACCTGCACCAGGCT-1
# 4      AAACCTGCACCATCCT-1
# ...                   ...
# 23627  TTTGTCAGTTTGACTG-3
# 23628  TTTGTCAGTTTGTTGG-3
# 23629  TTTGTCATCACAAACC-3
# 23630  TTTGTCATCAGCATGT-3
# 23631  TTTGTCATCTTAGAGC-3
#
# [23632 rows x 1 columns]

# %%
exp = anndata.read_mtx(f"/media/hdd/hb/lof/perturb_seq/geo_raw_data/jost_gse132080/GSE132080_10X_matrix.mtx")
exp
# Out:
# AnnData object with n_obs × n_vars = 33694 × 23633

# %%
barcode  = pd.read_csv(f"/media/hdd/hb/lof/perturb_seq/geo_raw_data/replogle_gse146194/{gsm_id}.barcodes.tsv", sep='\t', header=None, names=['cell_barcode'])
barcode.index = barcode['cell_barcode']
del barcode['cell_barcode']

cell_info = pd.read_csv(f"/media/hdd/hb/lof/perturb_seq/geo_raw_data/replogle_gse146194/{gsm_id}.raw_cell_identities.csv",)
# cell_info.drop(columns=['guide_identity', 'A', 'B', 'protospacer_A', 'protospacer_B'], inplace=True)
cell_info.index = cell_info['cell_barcode']
del cell_info['cell_barcode']

gene_info = pd.read_csv(f"/media/hdd/hb/lof/perturb_seq/geo_raw_data/replogle_gse146194/{gsm_id}.features.tsv", header=None, sep='\t',  names=['gene_id', 'gene_name', 'type' ])
gene_info.index = gene_info['gene_id']
del gene_info['gene_id']

# %%
# good_coverage == True만 뽑기
cell_info_f = cell_info[cell_info['good_coverage']!=False]
cell_info_f.good_coverage.unique()
# Out:
# array([ True])

# %%
# condition_list = []
# cell_info_f_condition = [x if x != 'Non-Targeting' else 'control' for x in cell_info_f.target ]
# cell_info_f.insert(0, 'condition', cell_info_f_condition)
# cell_info_f
cell_info_f['condition'] = [x for x in cell_info_f['target_A'] + '/' + cell_info_f['target_B'].values]
cell_info_f['condition'] = cell_info_f['condition'].str.replace('Non-Targeting/Non-Targeting', 'control')
cell_info_f['condition'] = cell_info_f['condition'].str.replace('Non-Targeting/', '')
cell_info_f['condition'] = cell_info_f['condition'].str.replace('/Non-Targeting', '')
cell_info_f
# Out:
#                                       guide_identity  num_guides  \
# cell_barcode
# AAACCCAAGGCATGGT-1        83-sgFDPS_2b|136-sgHUS1_2a           2
# AAACCCAAGTGTTCAC-1       252-sgFDPS_2b|331-sgHUS1_2a           2
# AAACCCAGTCACGACC-1  598-sgNegCtrl3b|1597-sgNegCtrl1a           2
# AAACCCAGTCAGCTTA-1   733-sgFDPSb|536-sgNegCtrl02093a           2
# AAACCCAGTGCTTATG-1          878-sgFDPSb|2107-sgHUS1a           2
# ...                                              ...         ...
# TTTGGTTTCCTCTCTT-1           216-sgFDPSb|864-sgRRM1a           2
# TTTGTTGGTGTCCATA-1    165-sgFDPSb|26-sgNegCtrl02093a           2
# TTTGTTGGTTTGGGAG-1         704-sgHUS1a|171-sgSREBF2b           2
# TTTGTTGTCCGAGCTG-1   295-sgHUS1b|232-sgNegCtrl02093a           2
# TTTGTTGTCTGGTGCG-1        501-sgHMGCRa|313-sgSREBF1b           2
#
#                                   A            B  representation  single  \
# cell_barcode
# AAACCCAAGGCATGGT-1        sgHUS1_2a    sgFDPS_2b             2.0     0.0
# AAACCCAAGTGTTCAC-1        sgHUS1_2a    sgFDPS_2b             2.0     0.0
# AAACCCAGTCACGACC-1      sgNegCtrl1a  sgNegCtrl3b             2.0     0.0
# AAACCCAGTCAGCTTA-1  sgNegCtrl02093a      sgFDPSb             4.0     1.0
# AAACCCAGTGCTTATG-1          sgHUS1a      sgFDPSb             4.0     0.0
# ...                             ...          ...             ...     ...
# TTTGGTTTCCTCTCTT-1          sgRRM1a      sgFDPSb             2.0     0.0
# TTTGTTGGTGTCCATA-1  sgNegCtrl02093a      sgFDPSb             4.0     1.0
# TTTGTTGGTTTGGGAG-1          sgHUS1a    sgSREBF2b             1.0     0.0
# TTTGTTGTCCGAGCTG-1  sgNegCtrl02093a      sgHUS1b             2.0     1.0
# TTTGTTGTCTGGTGCG-1         sgHMGCRa    sgSREBF1b             1.0     0.0
#
#                     double  essential  control         protospacer_A  ...  \
# cell_barcode                                                          ...
# AAACCCAAGGCATGGT-1     1.0        0.0      0.0  GAGCCGCGGCGGGCCTCTGT  ...
# AAACCCAAGTGTTCAC-1     1.0        0.0      0.0  GAGCCGCGGCGGGCCTCTGT  ...
# AAACCCAGTCACGACC-1     0.0        0.0      1.0  GGCCAAACGTGCCCTGACGG  ...
# AAACCCAGTCAGCTTA-1     0.0        0.0      0.0  GTCGAGCCGCGGCGTGCGCG  ...
# AAACCCAGTGCTTATG-1     1.0        0.0      0.0  GGGATGAAGGCGGCTTTCAA  ...
# ...                    ...        ...      ...                   ...  ...
# TTTGGTTTCCTCTCTT-1     1.0        0.0      0.0  GGACTGCGGCTCTAAAGCGC  ...
# TTTGTTGGTGTCCATA-1     0.0        0.0      0.0  GTCGAGCCGCGGCGTGCGCG  ...
# TTTGTTGGTTTGGGAG-1     1.0        0.0      0.0  GGGATGAAGGCGGCTTTCAA  ...
# TTTGTTGTCCGAGCTG-1     0.0        0.0      0.0  GTCGAGCCGCGGCGTGCGCG  ...
# TTTGTTGTCTGGTGCG-1     1.0        0.0      0.0  GACTAGAGGCCACCGAACCC  ...
#
#                            target_B umi_A umi_B read_count UMI_count  \
# cell_barcode
# AAACCCAAGGCATGGT-1  ENSG00000160752   136    83        100       100
# AAACCCAAGTGTTCAC-1  ENSG00000160752   331   252        100       100
# AAACCCAGTCACGACC-1    Non-Targeting  1597   598        100       100
# AAACCCAGTCAGCTTA-1  ENSG00000160752   536   733        100       100
# AAACCCAGTGCTTATG-1  ENSG00000160752  2107   878        100       100
# ...                             ...   ...   ...        ...       ...
# TTTGGTTTCCTCTCTT-1  ENSG00000160752   864   216        100       100
# TTTGTTGGTGTCCATA-1  ENSG00000160752    26   165        100       100
# TTTGTTGGTTTGGGAG-1  ENSG00000198911   704   171        100       100
# TTTGTTGTCCGAGCTG-1  ENSG00000136273   232   295        100       100
# TTTGTTGTCTGGTGCG-1  ENSG00000072310   501   313        100       100
#
#                     coverage  good_coverage  number_of_cells  gemgroup  \
# cell_barcode
# AAACCCAAGGCATGGT-1         2           True                1         1
# AAACCCAAGTGTTCAC-1         2           True                1         1
# AAACCCAGTCACGACC-1         2           True                1         1
# AAACCCAGTCAGCTTA-1         2           True                1         1
# AAACCCAGTGCTTATG-1         2           True                1         1
# ...                      ...            ...              ...       ...
# TTTGGTTTCCTCTCTT-1         2           True                1         1
# TTTGTTGGTGTCCATA-1         2           True                1         1
# TTTGTTGGTTTGGGAG-1         2           True                1         1
# TTTGTTGTCCGAGCTG-1         2           True                1         1
# TTTGTTGTCTGGTGCG-1         2           True                1         1
#
#                                           condition
# cell_barcode
# AAACCCAAGGCATGGT-1  ENSG00000136273/ENSG00000160752
# AAACCCAAGTGTTCAC-1  ENSG00000136273/ENSG00000160752
# AAACCCAGTCACGACC-1                          control
# AAACCCAGTCAGCTTA-1                  ENSG00000160752
# AAACCCAGTGCTTATG-1  ENSG00000136273/ENSG00000160752
# ...                                             ...
# TTTGGTTTCCTCTCTT-1  ENSG00000167325/ENSG00000160752
# TTTGTTGGTGTCCATA-1                  ENSG00000160752
# TTTGTTGGTTTGGGAG-1  ENSG00000136273/ENSG00000198911
# TTTGTTGTCCGAGCTG-1                  ENSG00000136273
# TTTGTTGTCTGGTGCG-1  ENSG00000113161/ENSG00000072310
#
# [6349 rows x 24 columns]

# %%
exp = exp.to_df().T

# %%
exp.obs = barcode
exp.var = gene_info
# Out:
# /tmp/ipykernel_2471198/2861986466.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   exp.obs = barcode

# %%
exp.index = barcode.index
exp.columns = gene_info.index

# %%
cell_info_f
# Out:
#                                       guide_identity  num_guides  \
# cell_barcode
# AAACCCAAGGCATGGT-1        83-sgFDPS_2b|136-sgHUS1_2a           2
# AAACCCAAGTGTTCAC-1       252-sgFDPS_2b|331-sgHUS1_2a           2
# AAACCCAGTCACGACC-1  598-sgNegCtrl3b|1597-sgNegCtrl1a           2
# AAACCCAGTCAGCTTA-1   733-sgFDPSb|536-sgNegCtrl02093a           2
# AAACCCAGTGCTTATG-1          878-sgFDPSb|2107-sgHUS1a           2
# ...                                              ...         ...
# TTTGGTTTCCTCTCTT-1           216-sgFDPSb|864-sgRRM1a           2
# TTTGTTGGTGTCCATA-1    165-sgFDPSb|26-sgNegCtrl02093a           2
# TTTGTTGGTTTGGGAG-1         704-sgHUS1a|171-sgSREBF2b           2
# TTTGTTGTCCGAGCTG-1   295-sgHUS1b|232-sgNegCtrl02093a           2
# TTTGTTGTCTGGTGCG-1        501-sgHMGCRa|313-sgSREBF1b           2
#
#                                   A            B  representation  single  \
# cell_barcode
# AAACCCAAGGCATGGT-1        sgHUS1_2a    sgFDPS_2b             2.0     0.0
# AAACCCAAGTGTTCAC-1        sgHUS1_2a    sgFDPS_2b             2.0     0.0
# AAACCCAGTCACGACC-1      sgNegCtrl1a  sgNegCtrl3b             2.0     0.0
# AAACCCAGTCAGCTTA-1  sgNegCtrl02093a      sgFDPSb             4.0     1.0
# AAACCCAGTGCTTATG-1          sgHUS1a      sgFDPSb             4.0     0.0
# ...                             ...          ...             ...     ...
# TTTGGTTTCCTCTCTT-1          sgRRM1a      sgFDPSb             2.0     0.0
# TTTGTTGGTGTCCATA-1  sgNegCtrl02093a      sgFDPSb             4.0     1.0
# TTTGTTGGTTTGGGAG-1          sgHUS1a    sgSREBF2b             1.0     0.0
# TTTGTTGTCCGAGCTG-1  sgNegCtrl02093a      sgHUS1b             2.0     1.0
# TTTGTTGTCTGGTGCG-1         sgHMGCRa    sgSREBF1b             1.0     0.0
#
#                     double  essential  control         protospacer_A  ...  \
# cell_barcode                                                          ...
# AAACCCAAGGCATGGT-1     1.0        0.0      0.0  GAGCCGCGGCGGGCCTCTGT  ...
# AAACCCAAGTGTTCAC-1     1.0        0.0      0.0  GAGCCGCGGCGGGCCTCTGT  ...
# AAACCCAGTCACGACC-1     0.0        0.0      1.0  GGCCAAACGTGCCCTGACGG  ...
# AAACCCAGTCAGCTTA-1     0.0        0.0      0.0  GTCGAGCCGCGGCGTGCGCG  ...
# AAACCCAGTGCTTATG-1     1.0        0.0      0.0  GGGATGAAGGCGGCTTTCAA  ...
# ...                    ...        ...      ...                   ...  ...
# TTTGGTTTCCTCTCTT-1     1.0        0.0      0.0  GGACTGCGGCTCTAAAGCGC  ...
# TTTGTTGGTGTCCATA-1     0.0        0.0      0.0  GTCGAGCCGCGGCGTGCGCG  ...
# TTTGTTGGTTTGGGAG-1     1.0        0.0      0.0  GGGATGAAGGCGGCTTTCAA  ...
# TTTGTTGTCCGAGCTG-1     0.0        0.0      0.0  GTCGAGCCGCGGCGTGCGCG  ...
# TTTGTTGTCTGGTGCG-1     1.0        0.0      0.0  GACTAGAGGCCACCGAACCC  ...
#
#                            target_B umi_A umi_B read_count UMI_count  \
# cell_barcode
# AAACCCAAGGCATGGT-1  ENSG00000160752   136    83        100       100
# AAACCCAAGTGTTCAC-1  ENSG00000160752   331   252        100       100
# AAACCCAGTCACGACC-1    Non-Targeting  1597   598        100       100
# AAACCCAGTCAGCTTA-1  ENSG00000160752   536   733        100       100
# AAACCCAGTGCTTATG-1  ENSG00000160752  2107   878        100       100
# ...                             ...   ...   ...        ...       ...
# TTTGGTTTCCTCTCTT-1  ENSG00000160752   864   216        100       100
# TTTGTTGGTGTCCATA-1  ENSG00000160752    26   165        100       100
# TTTGTTGGTTTGGGAG-1  ENSG00000198911   704   171        100       100
# TTTGTTGTCCGAGCTG-1  ENSG00000136273   232   295        100       100
# TTTGTTGTCTGGTGCG-1  ENSG00000072310   501   313        100       100
#
#                     coverage  good_coverage  number_of_cells  gemgroup  \
# cell_barcode
# AAACCCAAGGCATGGT-1         2           True                1         1
# AAACCCAAGTGTTCAC-1         2           True                1         1
# AAACCCAGTCACGACC-1         2           True                1         1
# AAACCCAGTCAGCTTA-1         2           True                1         1
# AAACCCAGTGCTTATG-1         2           True                1         1
# ...                      ...            ...              ...       ...
# TTTGGTTTCCTCTCTT-1         2           True                1         1
# TTTGTTGGTGTCCATA-1         2           True                1         1
# TTTGTTGGTTTGGGAG-1         2           True                1         1
# TTTGTTGTCCGAGCTG-1         2           True                1         1
# TTTGTTGTCTGGTGCG-1         2           True                1         1
#
#                                           condition
# cell_barcode
# AAACCCAAGGCATGGT-1  ENSG00000136273/ENSG00000160752
# AAACCCAAGTGTTCAC-1  ENSG00000136273/ENSG00000160752
# AAACCCAGTCACGACC-1                          control
# AAACCCAGTCAGCTTA-1                  ENSG00000160752
# AAACCCAGTGCTTATG-1  ENSG00000136273/ENSG00000160752
# ...                                             ...
# TTTGGTTTCCTCTCTT-1  ENSG00000167325/ENSG00000160752
# TTTGTTGGTGTCCATA-1                  ENSG00000160752
# TTTGTTGGTTTGGGAG-1  ENSG00000136273/ENSG00000198911
# TTTGTTGTCCGAGCTG-1                  ENSG00000136273
# TTTGTTGTCTGGTGCG-1  ENSG00000113161/ENSG00000072310
#
# [6349 rows x 24 columns]

# %%
exp = exp[exp.index.isin(cell_info_f.index)]
cell_info_f = cell_info_f[cell_info_f.index.isin(exp.index)]

# %%
exp.obs = cell_info_f
exp.var = gene_info
# Out:
# /tmp/ipykernel_2471198/3746570333.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   exp.obs = cell_info_f

# %%
exp.sort_index(inplace=True)
cell_info_f.sort_index(inplace=True)

# %%
adata = anndata.AnnData(X=exp, obs=cell_info_f, var=gene_info)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6310 × 33694
#     obs: 'guide_identity', 'num_guides', 'A', 'B', 'representation', 'single', 'double', 'essential', 'control', 'protospacer_A', 'protospacer_B', 'gene_A', 'gene_B', 'target_A', 'target_B', 'umi_A', 'umi_B', 'read_count', 'UMI_count', 'coverage', 'good_coverage', 'number_of_cells', 'gemgroup', 'condition'
#     var: 'gene_name', 'type'

# %%
cell_info_f.condition.value_counts(), len(cell_info_f['condition'].unique())
# Out:
# (control                            759
#  ENSG00000136273/ENSG00000160752    632
#  ENSG00000136273                    577
#  ENSG00000160752                    430
#  ENSG00000113161/ENSG00000136273    269
#                                    ...
#  ENSG00000102145                      4
#  ENSG00000171848/ENSG00000160752      3
#  ENSG00000171848                      2
#  ENSG00000163882                      2
#  ENSG00000058262                      1
#  Name: condition, Length: 79, dtype: int64,
#  79)

# %%
gsm_id
# Out:
# 'GSM4367988_exp10'

# %%
import hdf5plugin
adata.write_h5ad(f"/media/hdd/hb/lof/perturb_seq/raw_preprocessing/replogle_{gsm_id}.h5ad",
    compression=hdf5plugin.FILTERS["zstd"]
)

# %%
adata = anndata.read_h5ad("/media/hdd/hb/lof/perturb_seq/raw_preprocessing/replogle_gsm4367985.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 37238 × 33748
#     obs: 'num_guides', 'representation', 'single', 'double', 'essential', 'control', 'gene_A', 'gene_B', 'target_A', 'target_B', 'umi_A', 'umi_B', 'read_count', 'UMI_count', 'coverage', 'good_coverage', 'number_of_cells', 'gemgroup', 'condition'
#     var: 'gene_name', 'type'
